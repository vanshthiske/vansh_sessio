# %%
import sklearn
from sklearn.datasets import fetch_california_housing

# %%
import warnings 
from sklearn.datasets import fetch_california_housing
from statsmodels.stats.outliers_influence import variance_inflation_factor
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import pandas as pd
warnings.filterwarnings('ignore')
california = fetch_california_housing(as_frame=True)
california_df=california['frame']
###################################
X=california_df.drop('MedHouseVal',axis=1)
y=california_df['MedHouseVal']
X.values
###############################
vif=[variance_inflation_factor(X.values,i) for i in range (len(X.columns))]
vif_data=pd.DataFrame(vif,index=X.columns,columns=['vif'])
vif_data.sort_values(by='vif',ascending=False)
########################################################
cols1=vif_data[vif_data['vif']<15].index
cols1=cols1.to_list()
vif_data[vif_data['vif']>15].index
cols2=['AveRooms','Latitude']
final_cols=cols1+cols2
####################################
final_df=X[final_cols]
final_df['MedHouseVal']=y
final_df
# Out:
#        MedInc  HouseAge  Population  AveOccup  AveRooms  Latitude  MedHouseVal
# 0      8.3252      41.0       322.0  2.555556  6.984127     37.88        4.526
# 1      8.3014      21.0      2401.0  2.109842  6.238137     37.86        3.585
# 2      7.2574      52.0       496.0  2.802260  8.288136     37.85        3.521
# 3      5.6431      52.0       558.0  2.547945  5.817352     37.85        3.413
# 4      3.8462      52.0       565.0  2.181467  6.281853     37.85        3.422
# ...       ...       ...         ...       ...       ...       ...          ...
# 20635  1.5603      25.0       845.0  2.560606  5.045455     39.48        0.781
# 20636  2.5568      18.0       356.0  3.122807  6.114035     39.49        0.771
# 20637  1.7000      17.0      1007.0  2.325635  5.205543     39.43        0.923
# 20638  1.8672      18.0       741.0  2.123209  5.329513     39.43        0.847
# 20639  2.3886      16.0      1387.0  2.616981  5.254717     39.37        0.894
#
# ...

# %%
X=final_df.drop("MedHouseVal",axis=1)
y=final_df['MedHouseVal']
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
X_scaled=ss.fit_transform(X)
X_scaled_df=pd.DataFrame(X_scaled,columns=X.columns)
X_scaled_df
# Out:
#          MedInc  HouseAge  Population  AveOccup  AveRooms  Latitude
# 0      2.344766  0.982143   -0.974429 -0.049597  0.628559  1.052548
# 1      2.332238 -0.607019    0.861439 -0.092512  0.327041  1.043185
# 2      1.782699  1.856182   -0.820777 -0.025843  1.155620  1.038503
# 3      0.932968  1.856182   -0.766028 -0.050329  0.156966  1.038503
# 4     -0.012881  1.856182   -0.759847 -0.085616  0.344711  1.038503
# ...         ...       ...         ...       ...       ...       ...
# 20635 -1.216128 -0.289187   -0.512592 -0.049110 -0.155023  1.801647
# 20636 -0.691593 -0.845393   -0.944405  0.005021  0.276881  1.806329
# 20637 -1.142593 -0.924851   -0.369537 -0.071735 -0.090318  1.778237
# 20638 -1.054583 -0.845393   -0.604429 -0.091225 -0.040211  1.778237
# 20639 -0.780129 -1.004309   -0.033977 -0.043682 -0.070443  1.750146
#
# [20640 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_scaled_df,y,test_size=0.2,random_state=1234)
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_test,y_test)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)
y_pred
# Out:
# array([2.30473678, 3.26212585, 2.25235989, ..., 1.39434401, 2.39395217,
#        1.71946446])

# %%
lr.intercept_
# Out:
# 2.064461711696833

# %%
lr.intercept_+np.sum(lr.coef_*X_test.values[0])
# Out:
# 2.3047367848866993

# %%
X_test
# Out:
#          MedInc  HouseAge  Population  AveOccup  AveRooms  Latitude
# 15712 -0.099733  1.856182   -0.716577 -0.129594 -0.234704  1.010411
# 4119   0.885225  1.856182    0.367812 -0.009598  0.282943 -0.698469
# 15725  0.002279  1.220517   -0.763379 -0.129966 -0.278781  1.005730
# 14616 -0.210589 -0.686477    0.350151  0.031639 -0.062546 -1.325839
# 13238  2.027992 -1.481058   -0.180564  0.035508  1.045992 -0.703151
# ...         ...       ...         ...       ...       ...       ...
# 13521  0.703519 -0.686477   -0.779274 -0.017558  0.299587 -0.651651
# 16913  5.011449 -0.289187    0.071989 -0.007758  1.390417  0.898047
# 20069 -0.699541  0.108104   -1.045073 -0.045110 -0.138627  1.113413
# 446    0.002279  1.856182   -0.917913 -0.113472 -0.421058  1.047866
# 2209  -0.060887 -1.083767   -0.366005  0.003862 -0.026645  0.551589
#
# [4128 rows x 6 columns]

# %%
eval_df=X_test
eval_df['y_actual']=y_test
eval_df['y_pred']=y_pred
eval_df
# Out:
#          MedInc  HouseAge  Population  AveOccup  AveRooms  Latitude  y_actual  \
# 15712 -0.099733  1.856182   -0.716577 -0.129594 -0.234704  1.010411   5.00000
# 4119   0.885225  1.856182    0.367812 -0.009598  0.282943 -0.698469   2.93900
# 15725  0.002279  1.220517   -0.763379 -0.129966 -0.278781  1.005730   4.12500
# 14616 -0.210589 -0.686477    0.350151  0.031639 -0.062546 -1.325839   1.57600
# 13238  2.027992 -1.481058   -0.180564  0.035508  1.045992 -0.703151   3.04100
# ...         ...       ...         ...       ...       ...       ...       ...
# 13521  0.703519 -0.686477   -0.779274 -0.017558  0.299587 -0.651651   1.64300
# 16913  5.011449 -0.289187    0.071989 -0.007758  1.390417  0.898047   5.00001
# 20069 -0.699541  0.108104   -1.045073 -0.045110 -0.138627  1.113413   1.23200
# 446    0.002279  1.856182   -0.917913 -0.113472 -0.421058  1.047866   1.82600
# 2209  -0.060887 -1.083767   -0.366005  0.003862 -0.026645  0.551589   0.68000
#
#          y_pred
# ...

# %%
y_actual =eval_df['y_actual']
y_pred=eval_df['y_pred']
error=[i-j for i,j in zip(y_actual,y_pred)]
summ=0
for i in error:
    square=i*i
    summ=summ+square

summ/len(eval_df)
# Out:
# 0.6676008481118304

# %%
np.sum(np.square(eval_df['y_actual'].values-eval_df['y_pred'].values))/len(eval_df)
# Out:
# 0.6676008481118304

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 0.6676008481118304

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(y_test,y_pred)
r2_score=r2_score(y_test,y_pred)
rmse=np.sqrt(mse)
print('Mse:',mse)
print('Rmse:',rmse)
print('rmsc',r2_score)
# Out:
# Mse: 0.6676008481118304
# Rmse: 0.8170684476295914
# rmsc 0.5065090715994581

# %%
0.8170684476295914*0.8170684476295914
# Out:
# 0.6676008481118304

# %% [markdown]
# **save the model**
# - in order to save the model we have two methods
# - pickle
# - joblib

# %% [markdown]
# **pickle**
# - it is similar to file handling session
#
# - open('filename.txt','w')
#
# - open('model.pkl','wb')
#
# - in order to save wee have a methods: dump
#
# - pickle.load(open('model.pkl','r'),model_variable_name)
#
# - pickle.dump(open('model.pkl','wb'),model_variable_name)

# %%
lr
# Out:
# LinearRegression()

# %%
import pickle
path=open('linear_regession_california.pkl','wb')
pickle.dump(lr,path)

# %%
with open('linear_regession_california1.pkl','wb') as file:
    pickle.dump(lr,file)

# %%
path=open('linear_regession_california.pkl','rb')
loaded_model=pickle.load(path)
loaded_model
# Out:
# LinearRegression()

# %% [markdown]
# **prediction**
#
# - we developed the model with 6 columns
#
# - so while providing the data we need to provide 6 values
#
# - there are two types of predictions
#
# - real time prediction
#
# - application wise pass a one sample at a time
#
# - Batch predition
#
# - multple sample value wee need to pass to the model it is same like X_test

# %%
loaded_model.predict([[1,2,3,4,5,7]])
# Out:
# array([2.24801168])

# %%
model done

# %%
model save method 2 joblib

# %%
import joblib

# %%
joblib.dump(lr,'linear_regression_california.joblib')
# Out:
# ['linear_regression_california.joblib']

# %%
saved_model=joblib.load('linear_regression_california.joblib')
saved_model
# Out:
# LinearRegression()

# %%
saved_model.predict([[1,2,3,4,5,6]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 saved_model.predict([[1,2,3,4,5,6]])
#
# NameError: name 'saved_model' is not defined
